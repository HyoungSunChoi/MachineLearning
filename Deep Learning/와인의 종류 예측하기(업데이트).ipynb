# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.callbacks import ModelCheckpoint

import pandas as pd
import numpy
import os
import tensorflow.compat.v1 as tf
tf.disable_v2_behavior()

# seed 값 설정
seed=0
numpy.random.seed(seed)
tf.set_random_seed(seed)

df_pre = pd.read_csv('./dataset/wine.csv', header=None)
df = df_pre.sample(frac=1)

dataset=df.values
X=dataset[:, 0:12]
y = dataset[:,12]

# 모델의 설정
model = Sequential()
model.add(Dense(30, input_dim=12, activation='relu'))
model.add(Dense(12, activation='relu'))
model.add(Dense(8, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# 모델 컴파일
model.compile(loss='binary_crossentropy',
             optimizer='adam',
              metrics=['accuracy'])

# 모델 저장 폴더 설정
MODEL_DIR='./model'
if not os.path.exists(MODEL_DIR):
    os.mkdir(MODEL_DIR)

# 모델 저장 조건 설정
modelpath='./model/{epoch:02d}-{val_loss:.4f}.hdf5'
checkpointer = ModelCheckpoint(filepath=modelpath, monitor='val_loss', verbose=1, save_best_only=True)

#  모델 실행 및 저장
model.fit(X, y, validation_split=0.2, epochs=200, batch_size=200, verbose=0, callbacks=[checkpointer])
# Out:
# Epoch 00001: val_loss improved from inf to 0.41613, saving model to ./model\01-0.4161.hdf5
#
# Epoch 00002: val_loss improved from 0.41613 to 0.30128, saving model to ./model\02-0.3013.hdf5
#
# Epoch 00003: val_loss improved from 0.30128 to 0.23694, saving model to ./model\03-0.2369.hdf5
#
# Epoch 00004: val_loss improved from 0.23694 to 0.22043, saving model to ./model\04-0.2204.hdf5
#
# Epoch 00005: val_loss improved from 0.22043 to 0.21589, saving model to ./model\05-0.2159.hdf5
#
# Epoch 00006: val_loss improved from 0.21589 to 0.21309, saving model to ./model\06-0.2131.hdf5
#
# Epoch 00007: val_loss improved from 0.21309 to 0.21123, saving model to ./model\07-0.2112.hdf5
#
# Epoch 00008: val_loss improved from 0.21123 to 0.20958, saving model to ./model\08-0.2096.hdf5
#
# Epoch 00009: val_loss improved from 0.20958 to 0.20790, saving model to ./model\09-0.2079.hdf5
#
# Epoch 00010: val_loss improved from 0.20790 to 0.20758, saving model to ./model\10-0.2076.hdf5
#
# Epoch 00011: val_loss improved from 0.20758 to 0.20668, saving model to ./model\11-0.2067.hdf5
#
# Epoch 00012: val_loss improved from 0.20668 to 0.20226, saving model to ./model\12-0.2023.hdf5
#
# Epoch 00013: val_loss improved from 0.20226 to 0.20104, saving model to ./model\13-0.2010.hdf5
#
# Epoch 00014: val_loss improved from 0.20104 to 0.19985, saving model to ./model\14-0.1998.hdf5
#
# Epoch 00015: val_loss improved from 0.19985 to 0.19792, saving model to ./model\15-0.1979.hdf5
#
# Epoch 00016: val_loss improved from 0.19792 to 0.19606, saving model to ./model\16-0.1961.hdf5
#
# Epoch 00017: val_loss improved from 0.19606 to 0.19485, saving model to ./model\17-0.1948.hdf5
#
# Epoch 00018: val_loss improved from 0.19485 to 0.19345, saving model to ./model\18-0.1934.hdf5
#
# Epoch 00019: val_loss improved from 0.19345 to 0.19215, saving model to ./model\19-0.1921.hdf5
#
# Epoch 00020: val_loss improved from 0.19215 to 0.19191, saving model to ./model\20-0.1919.hdf5
#
# Epoch 00021: val_loss improved from 0.19191 to 0.19127, saving model to ./model\21-0.1913.hdf5
#
# Epoch 00022: val_loss improved from 0.19127 to 0.18825, saving model to ./model\22-0.1883.hdf5
#
# Epoch 00023: val_loss improved from 0.18825 to 0.18665, saving model to ./model\23-0.1866.hdf5
#
# Epoch 00024: val_loss improved from 0.18665 to 0.18518, saving model to ./model\24-0.1852.hdf5
#
# Epoch 00025: val_loss improved from 0.18518 to 0.18257, saving model to ./model\25-0.1826.hdf5
#
# Epoch 00026: val_loss improved from 0.18257 to 0.18047, saving model to ./model\26-0.1805.hdf5
#
# Epoch 00027: val_loss improved from 0.18047 to 0.17907, saving model to ./model\27-0.1791.hdf5
#
# Epoch 00028: val_loss improved from 0.17907 to 0.17387, saving model to ./model\28-0.1739.hdf5
#
# Epoch 00029: val_loss improved from 0.17387 to 0.17307, saving model to ./model\29-0.1731.hdf5
#
# Epoch 00030: val_loss improved from 0.17307 to 0.17096, saving model to ./model\30-0.1710.hdf5
#
# Epoch 00031: val_loss improved from 0.17096 to 0.17055, saving model to ./model\31-0.1706.hdf5
#
# Epoch 00032: val_loss improved from 0.17055 to 0.16896, saving model to ./model\32-0.1690.hdf5
#
# Epoch 00033: val_loss improved from 0.16896 to 0.16457, saving model to ./model\33-0.1646.hdf5
#
# Epoch 00034: val_loss improved from 0.16457 to 0.16097, saving model to ./model\34-0.1610.hdf5
#
# Epoch 00035: val_loss improved from 0.16097 to 0.15666, saving model to ./model\35-0.1567.hdf5
#
# Epoch 00036: val_loss improved from 0.15666 to 0.15074, saving model to ./model\36-0.1507.hdf5
#
# Epoch 00037: val_loss improved from 0.15074 to 0.14516, saving model to ./model\37-0.1452.hdf5
#
# Epoch 00038: val_loss improved from 0.14516 to 0.14287, saving model to ./model\38-0.1429.hdf5
#
# Epoch 00039: val_loss improved from 0.14287 to 0.14008, saving model to ./model\39-0.1401.hdf5
#
# Epoch 00040: val_loss did not improve from 0.14008
#
# Epoch 00041: val_loss did not improve from 0.14008
#
# Epoch 00042: val_loss improved from 0.14008 to 0.13011, saving model to ./model\42-0.1301.hdf5
#
# Epoch 00043: val_loss improved from 0.13011 to 0.12532, saving model to ./model\43-0.1253.hdf5
#
# Epoch 00044: val_loss improved from 0.12532 to 0.12176, saving model to ./model\44-0.1218.hdf5
#
# Epoch 00045: val_loss improved from 0.12176 to 0.11820, saving model to ./model\45-0.1182.hdf5
#
# Epoch 00046: val_loss did not improve from 0.11820
#
# Epoch 00047: val_loss improved from 0.11820 to 0.11151, saving model to ./model\47-0.1115.hdf5
#
# Epoch 00048: val_loss improved from 0.11151 to 0.10880, saving model to ./model\48-0.1088.hdf5
#
# Epoch 00049: val_loss did not improve from 0.10880
#
# Epoch 00050: val_loss did not improve from 0.10880
#
# Epoch 00051: val_loss improved from 0.10880 to 0.10160, saving model to ./model\51-0.1016.hdf5
#
# Epoch 00052: val_loss improved from 0.10160 to 0.09752, saving model to ./model\52-0.0975.hdf5
#
# Epoch 00053: val_loss improved from 0.09752 to 0.09433, saving model to ./model\53-0.0943.hdf5
#
# Epoch 00054: val_loss improved from 0.09433 to 0.09061, saving model to ./model\54-0.0906.hdf5
#
# Epoch 00055: val_loss improved from 0.09061 to 0.08880, saving model to ./model\55-0.0888.hdf5
#
# Epoch 00056: val_loss improved from 0.08880 to 0.08702, saving model to ./model\56-0.0870.hdf5
#
# Epoch 00057: val_loss improved from 0.08702 to 0.08496, saving model to ./model\57-0.0850.hdf5
#
# Epoch 00058: val_loss did not improve from 0.08496
#
# Epoch 00059: val_loss improved from 0.08496 to 0.08098, saving model to ./model\59-0.0810.hdf5
#
# Epoch 00060: val_loss improved from 0.08098 to 0.08072, saving model to ./model\60-0.0807.hdf5
#
# Epoch 00061: val_loss improved from 0.08072 to 0.07902, saving model to ./model\61-0.0790.hdf5
#
# Epoch 00062: val_loss did not improve from 0.07902
#
# Epoch 00063: val_loss did not improve from 0.07902
#
# Epoch 00064: val_loss improved from 0.07902 to 0.07530, saving model to ./model\64-0.0753.hdf5
#
# Epoch 00065: val_loss improved from 0.07530 to 0.07399, saving model to ./model\65-0.0740.hdf5
#
# Epoch 00066: val_loss improved from 0.07399 to 0.07125, saving model to ./model\66-0.0712.hdf5
#
# Epoch 00067: val_loss did not improve from 0.07125
#
# Epoch 00068: val_loss did not improve from 0.07125
#
# Epoch 00069: val_loss improved from 0.07125 to 0.06941, saving model to ./model\69-0.0694.hdf5
#
# Epoch 00070: val_loss did not improve from 0.06941
#
# Epoch 00071: val_loss improved from 0.06941 to 0.06674, saving model to ./model\71-0.0667.hdf5
#
# Epoch 00072: val_loss did not improve from 0.06674
#
# Epoch 00073: val_loss improved from 0.06674 to 0.06622, saving model to ./model\73-0.0662.hdf5
#
# Epoch 00074: val_loss did not improve from 0.06622
#
# Epoch 00075: val_loss improved from 0.06622 to 0.06409, saving model to ./model\75-0.0641.hdf5
#
# Epoch 00076: val_loss improved from 0.06409 to 0.06278, saving model to ./model\76-0.0628.hdf5
#
# Epoch 00077: val_loss improved from 0.06278 to 0.06216, saving model to ./model\77-0.0622.hdf5
#
# Epoch 00078: val_loss did not improve from 0.06216
#
# Epoch 00079: val_loss did not improve from 0.06216
#
# Epoch 00080: val_loss improved from 0.06216 to 0.06181, saving model to ./model\80-0.0618.hdf5
#
# Epoch 00081: val_loss improved from 0.06181 to 0.06103, saving model to ./model\81-0.0610.hdf5
#
# Epoch 00082: val_loss improved from 0.06103 to 0.06013, saving model to ./model\82-0.0601.hdf5
#
# Epoch 00083: val_loss did not improve from 0.06013
#
# Epoch 00084: val_loss did not improve from 0.06013
#
# Epoch 00085: val_loss did not improve from 0.06013
#
# Epoch 00086: val_loss improved from 0.06013 to 0.05997, saving model to ./model\86-0.0600.hdf5
#
# Epoch 00087: val_loss did not improve from 0.05997
#
# Epoch 00088: val_loss improved from 0.05997 to 0.05926, saving model to ./model\88-0.0593.hdf5
#
# Epoch 00089: val_loss improved from 0.05926 to 0.05772, saving model to ./model\89-0.0577.hdf5
#
# Epoch 00090: val_loss did not improve from 0.05772
#
# Epoch 00091: val_loss improved from 0.05772 to 0.05726, saving model to ./model\91-0.0573.hdf5
#
# Epoch 00092: val_loss improved from 0.05726 to 0.05707, saving model to ./model\92-0.0571.hdf5
#
# Epoch 00093: val_loss did not improve from 0.05707
#
# Epoch 00094: val_loss did not improve from 0.05707
#
# Epoch 00095: val_loss improved from 0.05707 to 0.05683, saving model to ./model\95-0.0568.hdf5
#
# Epoch 00096: val_loss did not improve from 0.05683
# Epoch 00097: val_loss improved from 0.05683 to 0.05631, saving model to ./model\97-0.0563.hdf5
#
# Epoch 00098: val_loss did not improve from 0.05631
#
# Epoch 00099: val_loss did not improve from 0.05631
#
# Epoch 00100: val_loss improved from 0.05631 to 0.05582, saving model to ./model\100-0.0558.hdf5
#
# Epoch 00101: val_loss did not improve from 0.05582
#
# Epoch 00102: val_loss did not improve from 0.05582
#
# Epoch 00103: val_loss improved from 0.05582 to 0.05561, saving model to ./model\103-0.0556.hdf5
#
# Epoch 00104: val_loss did not improve from 0.05561
#
# Epoch 00105: val_loss improved from 0.05561 to 0.05556, saving model to ./model\105-0.0556.hdf5
#
# Epoch 00106: val_loss did not improve from 0.05556
#
# Epoch 00107: val_loss did not improve from 0.05556
#
# Epoch 00108: val_loss improved from 0.05556 to 0.05417, saving model to ./model\108-0.0542.hdf5
#
# Epoch 00109: val_loss did not improve from 0.05417
#
# Epoch 00110: val_loss did not improve from 0.05417
#
# Epoch 00111: val_loss did not improve from 0.05417
#
# Epoch 00112: val_loss did not improve from 0.05417
#
# Epoch 00113: val_loss did not improve from 0.05417
#
# Epoch 00114: val_loss did not improve from 0.05417
#
# Epoch 00115: val_loss did not improve from 0.05417
#
# Epoch 00116: val_loss improved from 0.05417 to 0.05394, saving model to ./model\116-0.0539.hdf5
#
# Epoch 00117: val_loss did not improve from 0.05394
#
# Epoch 00118: val_loss did not improve from 0.05394
#
# Epoch 00119: val_loss did not improve from 0.05394
#
# Epoch 00120: val_loss did not improve from 0.05394
#
# Epoch 00121: val_loss did not improve from 0.05394
#
# Epoch 00122: val_loss did not improve from 0.05394
#
# Epoch 00123: val_loss did not improve from 0.05394
#
# Epoch 00124: val_loss improved from 0.05394 to 0.05295, saving model to ./model\124-0.0530.hdf5
#
# Epoch 00125: val_loss did not improve from 0.05295
#
# Epoch 00126: val_loss did not improve from 0.05295
#
# Epoch 00127: val_loss did not improve from 0.05295
#
# Epoch 00128: val_loss did not improve from 0.05295
#
# Epoch 00129: val_loss did not improve from 0.05295
#
# Epoch 00130: val_loss did not improve from 0.05295
#
# Epoch 00131: val_loss did not improve from 0.05295
#
# Epoch 00132: val_loss did not improve from 0.05295
#
# Epoch 00133: val_loss did not improve from 0.05295
#
# Epoch 00134: val_loss did not improve from 0.05295
#
# Epoch 00135: val_loss did not improve from 0.05295
#
# Epoch 00136: val_loss did not improve from 0.05295
#
# Epoch 00137: val_loss did not improve from 0.05295
#
# Epoch 00138: val_loss did not improve from 0.05295
#
# Epoch 00139: val_loss improved from 0.05295 to 0.05291, saving model to ./model\139-0.0529.hdf5
#
# Epoch 00140: val_loss did not improve from 0.05291
#
# Epoch 00141: val_loss did not improve from 0.05291
#
# Epoch 00142: val_loss did not improve from 0.05291
#
# Epoch 00143: val_loss did not improve from 0.05291
#
# Epoch 00144: val_loss improved from 0.05291 to 0.05214, saving model to ./model\144-0.0521.hdf5
#
# Epoch 00145: val_loss did not improve from 0.05214
#
# Epoch 00146: val_loss did not improve from 0.05214
#
# Epoch 00147: val_loss did not improve from 0.05214
#
# Epoch 00148: val_loss did not improve from 0.05214
#
# Epoch 00149: val_loss did not improve from 0.05214
#
# Epoch 00150: val_loss did not improve from 0.05214
#
# Epoch 00151: val_loss did not improve from 0.05214
#
# Epoch 00152: val_loss did not improve from 0.05214
#
# Epoch 00153: val_loss did not improve from 0.05214
#
# Epoch 00154: val_loss did not improve from 0.05214
#
# Epoch 00155: val_loss did not improve from 0.05214
#
# Epoch 00156: val_loss did not improve from 0.05214
#
# Epoch 00157: val_loss improved from 0.05214 to 0.05200, saving model to ./model\157-0.0520.hdf5
#
# Epoch 00158: val_loss improved from 0.05200 to 0.05140, saving model to ./model\158-0.0514.hdf5
#
# Epoch 00159: val_loss did not improve from 0.05140
#
# Epoch 00160: val_loss did not improve from 0.05140
#
# Epoch 00161: val_loss did not improve from 0.05140
#
# Epoch 00162: val_loss did not improve from 0.05140
#
# Epoch 00163: val_loss improved from 0.05140 to 0.05123, saving model to ./model\163-0.0512.hdf5
#
# Epoch 00164: val_loss did not improve from 0.05123
#
# Epoch 00165: val_loss did not improve from 0.05123
#
# Epoch 00166: val_loss did not improve from 0.05123
#
# Epoch 00167: val_loss did not improve from 0.05123
#
# Epoch 00168: val_loss did not improve from 0.05123
#
# Epoch 00169: val_loss did not improve from 0.05123
#
# Epoch 00170: val_loss did not improve from 0.05123
#
# Epoch 00171: val_loss did not improve from 0.05123
#
# Epoch 00172: val_loss did not improve from 0.05123
#
# Epoch 00173: val_loss did not improve from 0.05123
#
# Epoch 00174: val_loss did not improve from 0.05123
#
# Epoch 00175: val_loss did not improve from 0.05123
#
# Epoch 00176: val_loss did not improve from 0.05123
#
# Epoch 00177: val_loss did not improve from 0.05123
#
# Epoch 00178: val_loss did not improve from 0.05123
#
# Epoch 00179: val_loss did not improve from 0.05123
#
# Epoch 00180: val_loss did not improve from 0.05123
#
# Epoch 00181: val_loss did not improve from 0.05123
#
# Epoch 00182: val_loss did not improve from 0.05123
#
# Epoch 00183: val_loss did not improve from 0.05123
#
# Epoch 00184: val_loss did not improve from 0.05123
#
# Epoch 00185: val_loss did not improve from 0.05123
#
# Epoch 00186: val_loss did not improve from 0.05123
#
# Epoch 00187: val_loss did not improve from 0.05123
#
# Epoch 00188: val_loss did not improve from 0.05123
#
# Epoch 00189: val_loss did not improve from 0.05123
#
# Epoch 00190: val_loss did not improve from 0.05123
#
# Epoch 00191: val_loss did not improve from 0.05123
#
# Epoch 00192: val_loss did not improve from 0.05123
#
# Epoch 00193: val_loss did not improve from 0.05123
#
# Epoch 00194: val_loss did not improve from 0.05123
#
# Epoch 00195: val_loss did not improve from 0.05123
#
# Epoch 00196: val_loss improved from 0.05123 to 0.05103, saving model to ./model\196-0.0510.hdf5
#
# Epoch 00197: val_loss did not improve from 0.05103
#
# Epoch 00198: val_loss did not improve from 0.05103
#
# Epoch 00199: val_loss did not improve from 0.05103
#
# Epoch 00200: val_loss did not improve from 0.05103

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-7-88744f80d965> in <module>
#       1 numpy.random.seed(seed)
# ----> 2 tf.set_random_seed(seed)
#
# AttributeError: module 'tensorflow' has no attribute 'set_random_seed'
